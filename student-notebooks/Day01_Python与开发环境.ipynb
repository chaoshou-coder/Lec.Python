# %% [markdown]
# # Day 01 · Python 与开发环境
#
# > **前置**: 零起点,不需要任何编程基础
# > **关键问题**: 程序是什么?程序 = 输入 → 处理 → 输出。今天先学会三件事:让电脑**说话**(print)、让电脑**听你打字**(input)、给数据**贴标签**(变量)。
#
# **引入:电子鹦鹉**
#
# 想象你养了一只电子鹦鹉,你对它说话它就重复。今天我们先让鹦鹉主动跟你打招呼 👋 —— 这就是你的第一句 Python 代码。

# %% [markdown]
# **1. print 输出**
#
# 类比:**print()** = 对着麦克风喊,全场都听到。括号里放你想让电脑显示的内容,运行后就会打印到屏幕上。

# %%
# 最经典的 Hello World
print("Hello World")

# 中文也行,直接写
print("你好,我是 Python")

# 一次打印多个值,逗号分隔 → 自动加空格
print("刘备", "关羽", "张飞")  # 刘备 关羽 张飞

# + 号拼接 → 没有空格
print("刘备" + "关羽")  # 刘备关羽

# %% [markdown]
# `\n` = **换行符**,遇到它就跳到下一行。`end=""` 可以取消 print 默认的末尾换行,让两次打印接在同一行。

# %%
# \n = 换行
print("第一行\n第二行")

# end="" 取消默认换行,两次打印接一起
print("不换行", end="")
print("接续这一行")  # 不换行接续这一行

# %% [markdown]
# **✏️ 练一练 ⭐**
#
# 用一句 `print` 输出自我介绍,包含姓名、年龄、爱好,三行显示。

# %%
# ======================
# 学员代码区
# ======================
print("姓名:小明")
print("年龄:18")
print("爱好:打篮球")

# %%
# 参考答案(用 \n 一行搞定)
print("姓名:小明\n年龄:18\n爱好:打篮球")

# %% [markdown]
# **2. input 输入**
#
# 类比:**input()** = 考试卷上的填空题,程序暂停,等你按回车才继续。括号里的字符串是提示语,不是结果。

# %%
# input 会暂停程序,等你按回车
name = input("请输入你的姓名:")

# 把你输入的内容拼出来
print("你好," + name)

# ⚠️ input 返回的是字符串 "18",不是数字 18
age = input("请输入年龄:")
print(type(age))  # <class 'str'>

# int() 把字符串转成整数,才能做数学运算
age_num = int(age)
print(type(age_num))  # <class 'int'>
print(age_num + 1)    # 可以算数了

# %% [markdown]
# **✏️ 练一练 ⭐**
#
# 输入姓名和年龄,拼接输出 `你好小明,你今年 18 岁`。

# %%
# ======================
# 学员代码区
# ======================
name = input("请输入姓名:")
age = input("请输入年龄:")
print("你好" + name + ",你今年" + age + "岁")

# %%
# 参考答案(用逗号自动加空格,更简洁)
name = input("请输入姓名:")
age = input("请输入年龄:")
print("你好", name + ",你今年" + age + "岁")

# %% [markdown]
# **3. type 查看类型**
#
# 电脑需要知道数据是什么类型,才能决定能不能做运算。**type()** = 放大镜,看数据的真实身份。Python 四种基本类型:**int** **float** **str** **bool**。

# %%
# 观察四种基本类型
print(type(42))       # <class 'int'>    整数
print(type(3.14))     # <class 'float'>  小数
print(type("hello"))  # <class 'str'>    字符串
print(type(True))     # <class 'bool'>   布尔

# 类型转换:字符串 ↔ 数字
print(int("42"))      # 42 (字符串 → 整数)
print(float("3.14"))  # 3.14 (字符串 → 小数)
print(str(100))       # "100" (数字 → 字符串)

# %% [markdown]
# **✏️ 练一练 ⭐⭐**
#
# 输入一个数字,输出它的类型和二倍值。
#
# 示例输入:`5` → 输出:`类型:<class 'int'>,二倍:10`

# %%
# ======================
# 学员代码区
# ======================
num = int(input("请输入一个数字:"))
print(type(num))
print("二倍:", num * 2)

# %%
# 参考答案
num = int(input("请输入一个数字:"))
print(f"类型:{type(num)},二倍:{num * 2}")

# %% [markdown]
# **4. 变量与赋值**
#
# 类比:**变量** = 快递柜上的取件码。把数据装进盒子,以后用名字就能找到它。**=** 是赋值,不是数学等号 —— 意思是"把右边的值装进左边的盒子"。

# %%
# 把数据装进盒子
name = "小明"        # 字符串 str
age = 18             # 整数 int
height = 1.75        # 浮点数 float
is_student = True    # 布尔 bool

# 查看每个盒子的类型
print(type(name))       # <class 'str'>
print(type(age))        # <class 'int'>
print(type(height))     # <class 'float'>
print(type(is_student)) # <class 'bool'>

# %% [markdown]
# 命名规则:由**字母、数字、下划线**组成;不能以数字开头;区分大小写;不能用保留字(if/for/while 等)。约定俗成:**snake_case**(小写 + 下划线)。

# %%
# ✅ 合法命名
user_name = "张三"
_age = 18
name2 = "李四"

# 赋值与重新赋值:x = x + 1 意思是自增
x = 10
x = x + 1  # 把 x+1 的结果装回 x
print(x)   # 11

# %% [markdown]
# **✏️ 练一练 ⭐⭐**
#
# 定义两个变量 `a = 10`, `b = 20`,交换它们的值并输出。
#
# 提示:借助第三个临时变量 `temp`。

# %%
# ======================
# 学员代码区
# ======================
a = 10
b = 20
temp = a
a = b
b = temp
print("a =", a, ", b =", b)

# %%
# 参考答案(Python 特色写法)
a = 10
b = 20
a, b = b, a
print(f"a = {a}, b = {b}")

# %% [markdown]
# **📝 本节试题集**
#
# 想更多练习?参见:
# - 当堂练:`course/lesson01/in_class/practice01-04.py`(4 道)
# - 课后作业:`course/lesson01/homework/task01-02.py`(2 道)
