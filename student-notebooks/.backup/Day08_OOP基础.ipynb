# %% [markdown]
# # Day 08 · OOP 基础
#
# **前置**: Day01-07 已掌握变量/字符串/分支/循环/函数/列表字典/文件 I/O/异常
# **关键问题**: 函数能把"行为"打包,但数据和行为是分离的 —— 能不能把数据和行为"粘"到一个盒子里?
# **本日目标**: 掌握类、构造函数、实例方法、类属性、@property、__str__ 六个核心概念,每个知识点后紧跟练习

# %% [markdown]
# # 知识点 1:类与构造函数(__init__ + self)
#
# **痛点:每次创建对象都要手动贴属性,容易遗漏**
#
# 之前用字典表示一只狗:`dog = {"name": "旺财", "age": 3}`,数据有了,但设置属性全靠手动,100 只狗就写 100 次。
#
# **解决方案:让"贴标签"自动化**
#
# 类就是"对象的蓝图",`__init__` 是构造函数,创建对象时自动执行。**`self`** 代表"当前正在创建的这个对象",调用时自动传入,不需要手动传。
#
# **语法模板**:
# ```python
# class 类名:
#     def __init__(self, 参数1, 参数2):
#         self.属性1 = 参数1
#         self.属性2 = 参数2
# ```

# %%
# 定义 Dog 类
class Dog:
    # __init__ 是构造函数,实例化时自动调用
    # self = 当前正在创建的对象(调用时自动传)
    # name, age = 外部传入的参数
    def __init__(self, name, age):
        self.name = name  # 把外部的 name 绑定到当前对象的 name 属性
        self.age = age    # 把外部的 age 绑定到当前对象的 age 属性

# --- 执行过程注释 ---
# 第 11 行 dog1 = Dog("旺财", 3):
#   ① Python 看到 Dog(...) → 创建新对象
#   ② 自动调用 __init__(self=新对象, name="旺财", age=3)
#   ③ self.name = "旺财" → 新对象的 name = "旺财"
#   ④ self.age = 3 → 新对象的 age = 3
#   ⑤ 把新对象赋值给变量 dog1
#
# 第 12 行 dog2 = Dog("来福", 5):
#   ① 同理创建第二个对象,name="来福", age=5
#   ② dog1 和 dog2 是两个独立的对象,互不影响
#
# 第 14 行 print(dog1.name):
#   ① 读取 dog1 的 name 属性 → "旺财"
#   ② 输出: 旺财

dog1 = Dog("旺财", 3)
dog2 = Dog("来福", 5)
print(dog1.name)  # 输出: 旺财
print(dog1.age)   # 输出: 3
print(dog2.name)  # 输出: 来福
print(dog2.age)   # 输出: 5

# %% [markdown]
# # 练习 1:定义 Book 类
#
# **题目**: 定义一个 `Book` 类,包含三个属性:`title`(书名)、`author`(作者)、`price`(价格)。实例化一本书并打印三个属性。
#
# > 问自己:
# > - 这个练习要用到今天学的哪个知识点?(类的定义 + __init__ + self)
# > - 题目中的 title/author/price 对应构造函数的哪几个参数?
# > - 属性应该写在谁的下面?(self 下面)
# > - 如果运行报错,检查:类名大驼峰了吗?冒号有没有忘?self 写了吗?
#
# **示例输出**:
# ```
# Python入门
# 李明
# 59.8
# ```

# %%
# ======================
# 学员代码区(pass 占位)
# ======================
pass

# %%
# ======================
# 参考答案
# ======================
class Book:
    def __init__(self, title, author, price):
        self.title = title    # 绑定书名
        self.author = author  # 绑定作者
        self.price = price    # 绑定价格

book = Book("Python入门", "李明", 59.8)
print(book.title)   # 输出: Python入门
print(book.author)  # 输出: 李明
print(book.price)   # 输出: 59.8

# %% [markdown]
# # 知识点 2:实例方法(self + def)
#
# **痛点:数据和行为分离,调用时不知道是谁在做**
#
# 之前写:`bark("旺财")` —— 你传进去的字符串到底是狗?猫?机器人?函数不知道。
#
# **解决方案:把行为"绑"到对象上**
#
# `dog.bark()` 比 `bark("旺财")` 更直观。实例方法的第一个参数写 **`self`**,哪个对象调用了它,self 就是谁。
#
# **语法模板**:
# ```python
# class 类名:
#     def 方法名(self, 其他参数):
#         return self.属性
# ```
#
# **易错**:调用时不要传 self,Python 会自动传。`dog.bark()` 等价于 `Dog.bark(dog)`。

# %%
class Dog:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    # 实例方法:bark 是狗能做的事
    # 第一个参数 self = 哪个对象调用了它,self 就是谁
    def bark(self):
        print(f"{self.name} 汪汪叫!")

    # 实例方法:把狗的年龄换算成人类年龄
    # self.age 读取当前对象的 age 属性
    def human_age(self):
        return self.age * 7

# --- 执行过程注释 ---
# 第 16 行 dog = Dog("旺财", 3):
#   ① 调用 __init__(self=dog, name="旺财", age=3)
#   ② dog.name = "旺财", dog.age = 3
#
# 第 19 行 dog.bark():
#   ① Python 看到 对象.方法名() → 调用实例方法
#   ② self = dog(自动传入,不需要你写)
#   ③ self.name 即 dog.name → "旺财"
#   ④ 输出: 旺财 汪汪叫!
#
# 第 22 行 result = dog.human_age():
#   ① self = dog
#   ② return self.age * 7 → 3 * 7 = 21
#   ③ result = 21

dog = Dog("旺财", 3)
dog.bark()                        # 输出: 旺财 汪汪叫!
result = dog.human_age()
print(f"相当于人类 {result} 岁")   # 输出: 相当于人类 21 岁

# %% [markdown]
# # 练习 2:给 Dog 添加 run(meters)方法
#
# **题目**: 在上面的 `Dog` 类中添加一个 `run(self, meters)` 方法,打印 `"{name} 跑了 {meters} 米"`,并返回一个字符串 `"跑了{meters}米"`。
#
# > 问自己:
# > - 实例方法的第一个参数应该写什么?(self)
# > - meters 应该写在 self 的后面还是前面?(后面)
# > - 方法内部要访问 name 属性,该怎么写?(self.name)
# > - 调用时,dog.run(100) 中的 100 对应哪个参数?(meters)
#
# **示例输出**:
# ```
# 旺财 跑了 100 米
# ```

# %%
# ======================
# 学员代码区(pass 占位)
# ======================
pass

# %%
# ======================
# 参考答案
# ======================
class Dog:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def run(self, meters):
        print(f"{self.name} 跑了 {meters} 米")
        return f"跑了{meters}米"

dog = Dog("旺财", 3)
result = dog.run(100)  # 输出: 旺财 跑了 100 米
print(result)          # 输出: 跑了100米

# %% [markdown]
# # 知识点 3:类属性 vs 实例属性
#
# **痛点:每创建一个对象都存一份相同的数据,浪费内存**
#
# 每只狗都是"哺乳类",如果每个对象都存一份 `species = "哺乳类"`,100 只狗就存 100 次。
#
# **解决方案:把"大家的"放类里,只存一次**
#
# - **类属性**:定义在类名下、方法外,**所有实例共享**,通过 `类名.属性` 访问
# - **实例属性**:通过 `self.属性` 绑定,**每个对象各有一份**
#
# **查找顺序**:`dog1.species` → 先看对象自身 → 找不到再看类 → 所以实例能"看到"类属性。
#
# **易错**:修改类属性要用 `类名.属性 = 值`,不要用 `self.属性 = 值`(那会创建一个同名的实例属性)。

# %%
class Dog:
    # 类属性:定义在类名下、方法外,所有 Dog 对象共享
    species = "哺乳类"
    legs = 4

    def __init__(self, name):
        # 实例属性:通过 self 绑定,每个对象独有
        self.name = name

# --- 执行过程注释 ---
# 第 11 行 dog1 = Dog("旺财"):
#   ① 调用 __init__(self=dog1, name="旺财")
#   ② dog1.name = "旺财"
#   注意:species 和 legs 没有变,它们是类属性,存在 Dog 类里而不是 dog1 里
#
# 第 12 行 dog2 = Dog("来福"):
#   ① dog2.name = "来福"
#
# 第 15 行 print(dog1.species):
#   ① 先看 dog1 对象自身有没有 species 属性 → 没有
#   ② 再看 Dog 类有没有 species 属性 → 有,"哺乳类"
#   ③ 输出: 哺乳类
#
# 第 19 行 print(Dog.species):
#   ① 直接访问 Dog 类的 species 属性
#   ② 输出: 哺乳类

dog1 = Dog("旺财")
dog2 = Dog("来福")

print(dog1.species)  # 输出: 哺乳类(从 Dog 类找到的)
print(dog2.species)  # 输出: 哺乳类(所有狗共享同一个 species)
print(dog1.name)     # 输出: 旺财(只有 dog1 自己有的属性)
print(dog2.name)     # 输出: 来福(只有 dog2 自己有的属性)

print(Dog.species)   # 输出: 哺乳类(通过类名直接访问)
print(Dog.legs)      # 输出: 4

# %% [markdown]
# # 练习 3:给 Student 添加类属性 school
#
# **题目**: 定义一个 `Student` 类,包含实例属性 `name`,以及**类属性** `school = "清华大学"`。创建两个学生实例,分别打印它们的 name 和 school。
#
# > 问自己:
# > - 类属性应该写在哪里?(类的下面、方法的外面)
# > - 实例属性应该写在哪里?(__init__ 里面、self 下面)
# > - 如果要访问 school,用 self.school 还是 Student.school?(两种都能,但推荐类名访问)
# > - 如果运行报错,检查:类属性缩进对不对?是不是写到 __init__ 里面了?
#
# **示例输出**:
# ```
# 小明 清华大学
# 小红 清华大学
# ```

# %%
# ======================
# 学员代码区(pass 占位)
# ======================
pass

# %%
# ======================
# 参考答案
# ======================
class Student:
    # 类属性:所有学生共享
    school = "清华大学"
    
    def __init__(self, name):
        # 实例属性:每个学生独有
        self.name = name

s1 = Student("小明")
s2 = Student("小红")
print(s1.name, Student.school)  # 输出: 小明 清华大学
print(s2.name, Student.school)  # 输出: 小红 清华大学

# %% [markdown]
# # 知识点 4:@property 把方法变成"属性"
#
# **痛点:数据可能被随意篡改**
#
# `student.score = -10` —— 成绩是负数!但 Python 不会报错。
#
# **解决方案:把属性"藏"起来,加一道"校验门"**
#
# `@property` = 在属性上加了一层"门禁":外面看起来像读属性,实际执行了一段校验逻辑。
#
# **三个核心概念**:
# - **getter**:`@property` 装饰,读取时触发
# - **setter**:`@属性名.setter` 装饰,赋值时触发校验
# - **私有约定**:`_属性名`(单下划线)表示"内部值,别直接改"
#
# **易错**:setter 装饰器名必须和 property **同名**,比如 `@score.setter`,不能写成 `@score_setter`。

# %%
class Student:
    def __init__(self, score):
        self._score = score  # 下划线约定:"私有,别直接改"

    @property
    def score(self):
        # 当你写 s.score 时,实际执行的是这个方法
        return self._score

    @score.setter
    def score(self, value):
        # 当你写 s.score = xxx 时,执行这个方法
        if 0 <= value <= 100:
            self._score = value
        else:
            print("成绩必须在 0-100 之间!")

# --- 执行过程注释 ---
# 第 18 行 s = Student(85):
#   ① 调用 __init__(self=s, score=85)
#   ② s._score = 85(存在"私有属性" _score 里,不是 score)
#
# 第 21 行 print(s.score):
#   ① Python 看到 s.score → 发现 score 被 @property 装饰了
#   ② 自动调用 score(self=s)方法
#   ③ return self._score → 85
#   ④ 输出: 85
#
# 第 23 行 s.score = 95:
#   ① Python 看到 s.score = ... → 发现 score 有 @score.setter
#   ② 自动调用 score(self=s, value=95)
#   ③ if 0 <= 95 <= 100 → True → self._score = 95
#
# 第 25 行 s.score = 120:
#   ① 自动调用 score(self=s, value=120)
#   ② if 0 <= 120 <= 100 → False → 走到 else
#   ③ 输出: 成绩必须在 0-100 之间!
#   ④ _score 保持原值 95

s = Student(85)
print(s.score)    # 输出: 85(调 getter)
s.score = 95
print(s.score)    # 输出: 95(调 setter 校验通过)
s.score = 120     # 输出: 成绩必须在 0-100 之间!(校验不通过)
print(s.score)    # 输出: 95(保持原值)

# %% [markdown]
# # 练习 4:给 Book 添加 price 的 setter
#
# **题目**: 给练习 1 的 `Book` 类添加 `@property` 和 `@price.setter`,要求:
# - `price` getter 直接返回 `_price`
# - `price` setter 校验:价格不能为负数,如果为负数则打印 `"价格不能为负数!"` 并保持原值不变
#
# > 问自己:
# > - @property 装饰的方法叫什么?(getter)
# > - setter 装饰器应该怎么写?(@price.setter)
# > - 私有属性名通常怎么命名?(_price)
# > - 校验不通过时应该怎么处理?(打印提示,不修改 _price)
# > - 如果运行报错,检查:setter 装饰器名是不是和 getter 同名?缩进对不对?
#
# **示例输出**:
# ```
# 59.8
# 价格不能为负数!
# 59.8
# ```

# %%
# ======================
# 学员代码区(pass 占位)
# ======================
pass

# %%
# ======================
# 参考答案
# ======================
class Book:
    def __init__(self, title, author, price):
        self.title = title
        self.author = author
        self._price = price  # 用 _price 存储真实值

    @property
    def price(self):
        return self._price

    @price.setter
    def price(self, value):
        if value < 0:
            print("价格不能为负数!")
        else:
            self._price = value
            
book = Book("Python入门", "李明", 59.8)
print(book.price)    # 输出: 59.8
book.price = -10     # 输出: 价格不能为负数!
print(book.price)    # 输出: 59.8(保持原值)

# %% [markdown]
# # 知识点 5:__str__ 定义对象的"自我介绍"
#
# **痛点:打印对象显示的是天书**
#
# `print(dog)` → `<__main__.Dog object at 0x7f8b2c>` 看不懂!
#
# **解决方案:让对象学会"自我介绍"**
#
# `__str__` 方法就像给对象发了一张"自我介绍卡" —— 以后有人 print 它,它就用这张卡片回答。
#
# **语法模板**:
# ```python
# def __str__(self):
#     return "要显示的字符串"
# ```
#
# **对比**:
# - `__str__`:`print(obj)` 时触发,给人看的
# - `__repr__`:`repr(obj)` 时触发,给开发者看的(本节不要求)

# %%
class Dog:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def __str__(self):
        # return 的字符串就是 print(dog) 时显示的内容
        return f"Dog(name={self.name}, age={self.age})"

# --- 执行过程注释 ---
# 第 10 行 dog = Dog("旺财", 3):
#   ① dog.name = "旺财", dog.age = 3
#
# 第 13 行 print(dog):
#   ① Python 看到 print(对象) → 自动查找该对象的 __str__ 方法
#   ② 找到 → 调用 __str__(self=dog)
#   ③ return f"Dog(name={self.name}, age={self.age})"
#   ④ self.name = "旺财", self.age = 3
#   ⑤ return "Dog(name=旺财, age=3)"
#   ⑥ print 输出: Dog(name=旺财, age=3)

dog = Dog("旺财", 3)
print(dog)  # 输出: Dog(name=旺财, age=3)

# %% [markdown]
# # 练习 5:给 Book 添加 __str__ 方法
#
# **题目**: 给练习 4 的 `Book` 类添加 `__str__` 方法,要求 `print(book)` 输出格式为 `"《书名》- 作者 著, 价格: XX元"`。
#
# > 问自己:
# > - __str__ 方法必须返回什么类型?(字符串)
# > - 如果返回了非字符串会怎样?(报错 TypeError)
# > - 书名应该用什么符号括起来?(《》)
# > - 如果运行报错,检查:__str__ 有没有双下划线?return 了吗?
#
# **示例输出**:
# ```
# 《Python入门》- 李明 著, 价格: 59.8元
# ```

# %%
# ======================
# 学员代码区(pass 占位)
# ======================
pass

# %%
# ======================
# 参考答案
# ======================
class Book:
    def __init__(self, title, author, price):
        self.title = title
        self.author = author
        self._price = price

    @property
    def price(self):
        return self._price

    @price.setter
    def price(self, value):
        if value < 0:
            print("价格不能为负数!")
        else:
            self._price = value

    def __str__(self):
        return f"《{self.title}》- {self.author} 著, 价格: {self._price}元"

book = Book("Python入门", "李明", 59.8)
print(book)  # 输出: 《Python入门》- 李明 著, 价格: 59.8元

# %% [markdown]
# # 今日小结
#
# **概念 vs 解决的痛点**:
#
# | 概念 | 解决的痛点 |
# |---|---|
# | `__init__`(构造函数) | 手动贴标签太麻烦,容易遗漏 |
# | `self`(实例方法的数据来源) | 数据和行为分离,调用时搞混 |
# | 类属性 vs 实例属性 | 重复定义浪费内存 |
# | `@property` | 数据可能被随意篡改 |
# | `__str__` | 打印对象显示内存地址,看不懂 |
#
# **语法要点**:
# - 定义方法:`def 方法名(self, 参数):` → 第一个参数永远是 self
# - 调用方法:`对象.方法名(参数)` → self 自动传,不需要手动传
# - 类属性用 `类名.属性` 修改,实例属性用 `self.属性` 修改
# - setter 装饰器名必须和 property 同名:`@属性名.setter`
#
# **本日错 3 件事**(课后把真实错例记录下来):
# 1. 漏写 `self` 参数,调用时报 `TypeError: bark() takes 0 positional arguments but 1 was given`
# 2. 给已有 `@property` 的 setter 写错装饰器名,setter 不生效
# 3. 改类属性用了 `self.count`,实际改了实例属性,类属性没变动
#
# **更多练习**:
# - 当堂练:`course/lesson08/in_class/practice01-06.py`
# - 课后作业:`course/lesson08/homework/task01-03.py`
