# %% [markdown]
# # Pandas 基础

# %% [markdown]
# **Pandas** 是 Python 数据分析最常用的第三方库,提供 **Series**(一维) 和 **DataFrame**(二维) 两种核心数据结构,配合丰富的查询、统计、排序方法,是数据处理的基本工具。

# %%
# 导入 pandas 库,约定俗成使用别名 pd
import pandas as pd

# %% [markdown]
# ## Series 序列

# %% [markdown]
# **Series** 是一维带索引的数组,本质上是"索引 + 值"的配对,类似于 Excel 中的一列。

# %%
# 导入 pandas
import pandas as pd

# 通过列表创建 Series,默认索引从 0 开始
s = pd.Series([10, 20, 30, 40])

# 打印 Series
print(s)

# %% [markdown]
# ## DataFrame 数据框

# %% [markdown]
# **DataFrame** 是二维表格型数据结构,由多列 Series 组成,每一列可以存放不同类型的数据,类似于 Excel 表格,是 Pandas 最核心的对象。

# %%
# 导入 pandas
import pandas as pd

# 用字典创建 DataFrame,键是列名,值是该列的数据列表
df_dict = pd.DataFrame({
    "name": ["张三", "李四", "王五"],
    "age": [18, 20, 19],
    "score": [88, 92, 75]
})

# 打印 DataFrame
print(df_dict)

# %%
# 导入 pandas
import pandas as pd

# 用列表创建 DataFrame,每行是一个列表,必须通过 columns 指定列名
df_list = pd.DataFrame(
    [["张三", 18, 88], ["李四", 20, 92], ["王五", 19, 75]],
    columns=["name", "age", "score"]
)

# 打印 DataFrame
print(df_list)

# %%
# 导入 pandas
import pandas as pd

# 使用 index 参数自定义行索引,不再使用默认的 0、1、2
df_idx = pd.DataFrame(
    {"name": ["张三", "李四", "王五"], "age": [18, 20, 19]},
    index=["a", "b", "c"]
)

# 打印 DataFrame
print(df_idx)

# %% [markdown]
# ## 查看 DataFrame 属性

# %% [markdown]
# 通过属性可以快速了解数据的**形状、列名、索引、数据类型**,是数据探索的第一步。

# %%
# 导入 pandas
import pandas as pd

# 创建示例 DataFrame
df = pd.DataFrame({
    "name": ["张三", "李四", "王五"],
    "age": [18, 20, 19],
    "score": [88, 92, 75]
})

# shape 返回 (行数, 列数)
print("shape:", df.shape)

# dtypes 返回每一列的数据类型
print("dtypes:", df.dtypes)

# columns 返回列名的索引对象
print("columns:", df.columns)

# index 返回行索引对象
print("index:", df.index)

# %% [markdown]
# ## 快速查看数据

# %% [markdown]
# **head / tail / info / describe** 是四个最常用的快速查看方法,分别用于查看头部、尾部、结构、统计信息。

# %%
# 导入 pandas
import pandas as pd

# 创建示例 DataFrame
df = pd.DataFrame({
    "name": ["张三", "李四", "王五", "赵六", "孙七"],
    "age": [18, 20, 19, 21, 22],
    "score": [88, 92, 75, 85, 90]
})

# head(n) 查看前 n 行,默认 n=5
print(df.head(3))

# tail(n) 查看后 n 行,默认 n=5
print(df.tail(2))

# %%
# 导入 pandas
import pandas as pd

# 创建示例 DataFrame
df = pd.DataFrame({
    "name": ["张三", "李四", "王五"],
    "age": [18, 20, 19],
    "score": [88, 92, 75]
})

# info() 显示列名、非空数量、数据类型、内存占用
df.info()

# describe() 显示数值列的统计摘要
print(df.describe())

# %% [markdown]
# ## 列选择

# %% [markdown]
# 通过**中括号**或**点号**可以选择单列或多列,返回 Series 或 DataFrame。

# %%
# 导入 pandas
import pandas as pd

# 创建示例 DataFrame
df = pd.DataFrame({
    "name": ["张三", "李四", "王五"],
    "age": [18, 20, 19],
    "score": [88, 92, 75]
})

# 选择单列:中括号 + 列名,返回 Series
print(df["name"])

# 选择多列:双层中括号 + 列名列表,返回 DataFrame
print(df[["name", "score"]])

# %%
# 导入 pandas
import pandas as pd

# 创建示例 DataFrame,列名不含空格时可用点号访问
df = pd.DataFrame({
    "name": ["张三", "李四", "王五"],
    "age": [18, 20, 19],
    "score": [88, 92, 75]
})

# 点号访问:等价于 df["name"],但不支持含空格的列名
print(df.name)

# %% [markdown]
# ## loc 与 iloc

# %% [markdown]
# **loc** 用**标签(列名/行索引名)** 选择数据,**iloc** 用**整数位置(0-based)** 选择数据。注意:loc 切片右端包含,iloc 切片右端不包含。

# %%
# 导入 pandas
import pandas as pd

# 创建示例 DataFrame
df = pd.DataFrame({
    "name": ["张三", "李四", "王五"],
    "age": [18, 20, 19],
    "score": [88, 92, 75]
})

# loc 用标签选择行(右端包含)
print(df.loc[0:1, "name":"age"])

# iloc 用整数位置选择(右端不包含)
print(df.iloc[0:2, 0:2])

# %% [markdown]
# ## 布尔过滤

# %% [markdown]
# **布尔过滤** 通过条件表达式筛选出满足条件的行。多个条件用 **& 且、| 或** 组合,每个条件必须用括号包裹。

# %%
# 导入 pandas
import pandas as pd

# 创建示例 DataFrame
df = pd.DataFrame({
    "name": ["张三", "李四", "王五"],
    "age": [18, 20, 19],
    "score": [88, 92, 75]
})

# 过滤:筛选分数大于 80 的行
print(df[df["score"] > 80])

# 多条件:年龄 >= 19 且 分数 > 80
print(df[(df["age"] >= 19) & (df["score"] > 80)])

# 多条件:年龄 < 19 或 分数等于 75
print(df[(df["age"] < 19) | (df["score"] == 75)])

# %% [markdown]
# ## 排序 sort_values

# %% [markdown]
# **sort_values** 按指定列的值对行进行排序,支持升序、降序、多列排序。

# %%
# 导入 pandas
import pandas as pd

# 创建示例 DataFrame
df = pd.DataFrame({
    "name": ["张三", "李四", "王五"],
    "age": [18, 20, 19],
    "score": [88, 92, 75]
})

# 按分数升序排序
print(df.sort_values("score"))

# 按分数降序排序
print(df.sort_values("score", ascending=False))

# 多列排序:先按年龄升序,年龄相同再按分数降序
print(df.sort_values(["age", "score"], ascending=[True, False]))

# %% [markdown]
# ## 更多练习

# %% [markdown]
# - 官方 10 分钟入门:https://pandas.pydata.org/docs/user_guide/10min.html
# - 练习数据集下载:https://github.com/guipsamora/pandas_exercises
